# %%
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
import envv2 as env_module
import agentv2 as agent_module

# %%
def plot_convergence(sw_history, pol_history, window=50):
    # Calcul des moyennes mobiles pour lisser le "bruit" du RL
    sw_smoothed = np.convolve(sw_history, np.ones(window)/window, mode='valid')
    pol_smoothed = np.convolve(pol_history, np.ones(window)/window, mode='valid')

    plt.figure(figsize=(14, 5))

    # Plot Social Welfare
    plt.subplot(1, 2, 1)
    plt.plot(sw_history, alpha=0.3, color='blue', label='Brut')
    plt.plot(sw_smoothed, color='darkblue', linewidth=2, label=f'Moyenne ({window})')
    plt.title("Évolution du Social Welfare ($SW$)")
    plt.xlabel("Épisodes")
    plt.ylabel("Score SW")
    plt.legend()
    plt.grid(True, alpha=0.3)

    # Plot Pollution
    plt.subplot(1, 2, 2)
    plt.plot(pol_history, alpha=0.3, color='red', label='Brut')
    plt.plot(pol_smoothed, color='darkred', linewidth=2, label=f'Moyenne ({window})')
    plt.title("Stock de Pollution Final")
    plt.xlabel("Épisodes")
    plt.ylabel("Niveau de Pollution")
    plt.legend()
    plt.grid(True, alpha=0.3)

    plt.tight_layout()
    plt.show()

# %%
def plot_firm_strategy(firm_agent, firm_name="Firme"):
    # On sépare les états de type Taxe (0)
    tax_states = sorted([s for s in firm_agent.q_table.keys() if s[0] == 0])
    
    if not tax_states:
        print("Pas assez de données dans la Q-table pour afficher la heatmap.")
        return

    # On construit la matrice : Lignes = Taxes, Colonnes = Quantités q
    q_matrix = np.array([firm_agent.q_table[s] for s in tax_states])
    tax_values = [s[1] for s in tax_states]
    q_values = np.round(firm_agent.actions, 1)

    plt.figure(figsize=(10, 6))
    sns.heatmap(q_matrix, annot=False, cmap="viridis", 
                yticklabels=tax_values, xticklabels=q_values)
    plt.title(f"Cerveau de la {firm_name} (États de Taxe)")
    plt.ylabel("Valeur de la Taxe imposée par l'État")
    plt.xlabel("Quantité $q$ produite (Action choisie)")
    plt.show()

# %%
def plot_gov_decisions(gov_agent):
    # On récupère les états (pollution) connus par le gouvernement
    states = sorted(gov_agent.q_table.keys())
    best_actions = []
    
    for s in states:
        idx = np.argmax(gov_agent.q_table[s])
        a_type, a_val = gov_agent.actions[idx]
        best_actions.append((s * 5, a_type, a_val)) # s*5 pour revenir à la pollution réelle

    # On sépare pour le plot
    pollutions = [x[0] for x in best_actions]
    types = ["Taxe" if x[1] == 0 else "Quota" for x in best_actions]
    values = [x[2] for x in best_actions]

    plt.figure(figsize=(12, 5))
    
    # Scatter plot pour voir le type et la valeur
    colors = ['blue' if t == "Taxe" else 'orange' for t in types]
    plt.scatter(pollutions, values, c=colors, s=100, edgecolors='black', alpha=0.7)
    
    plt.title("Politique optimale choisie selon le niveau de Pollution")
    plt.xlabel("Niveau de Pollution")
    plt.ylabel("Valeur de la Politique (Taxe ou Quota)")
    plt.grid(True, linestyle='--', alpha=0.6)
    
    # Légende custom
    from matplotlib.lines import Line2D
    legend_elements = [Line2D([0], [0], marker='o', color='w', label='Taxe', markerfacecolor='blue', markersize=10),
                       Line2D([0], [0], marker='o', color='w', label='Quota', markerfacecolor='orange', markersize=10)]
    plt.legend(handles=legend_elements)
    plt.show()

# %%
history_sw = []
history_pol = []

# --- Initialisation ---
env = env_module.EcoSystem()
gov = agent_module.GovernmentAgent()
firms = [agent_module.FirmAgent() for _ in range(env.n_firms)]

for ep in range(100000):
    state_vec = env.reset()
    pollution = state_vec[2]
    ep_sw = 0  # cumul du bien-être social
    
    for step in range(20):
        gov_idx = gov.get_action(pollution)
        a_type, a_val = gov.actions[gov_idx]
        
        q_indices, q_vals = [], []
        for f in firms:
            idx = f.get_action(a_type, a_val)
            q_indices.append(idx)
            q_vals.append(f.actions[idx])
            
        next_state_vec, reward_gov, rewards_firms = env.step_multi_firms(a_type, a_val, q_vals)
        next_pollution = next_state_vec[2]
        
        # Apprentissage
        for i in range(5):
            firms[i].learn(a_type, a_val, q_indices[i], rewards_firms[i])
        
        gov.learn(pollution, gov_idx, reward_gov, next_pollution)
        
        pollution = next_pollution
        ep_sw += reward_gov
    
    # --- FIN D'ÉPISODE ---
    history_sw.append(ep_sw)
    history_pol.append(pollution)
    
    gov.decay_epsilon() #decay à chaque épisode et non pas à chaque step 
    for f in firms:
        f.decay_epsilon()
    
    if ep % 1000 == 0:
        print(f"Épisode {ep} terminé. Epsilon Gov: {gov.epsilon:.2f}")
# Out:
# Épisode 0 terminé. Epsilon Gov: 1.00
# Épisode 1000 terminé. Epsilon Gov: 0.90
# Épisode 2000 terminé. Epsilon Gov: 0.82
# Épisode 3000 terminé. Epsilon Gov: 0.74
# Épisode 4000 terminé. Epsilon Gov: 0.67
# Épisode 5000 terminé. Epsilon Gov: 0.61
# Épisode 6000 terminé. Epsilon Gov: 0.55
# Épisode 7000 terminé. Epsilon Gov: 0.50
# Épisode 8000 terminé. Epsilon Gov: 0.45
# Épisode 9000 terminé. Epsilon Gov: 0.41
# Épisode 10000 terminé. Epsilon Gov: 0.37
# Épisode 11000 terminé. Epsilon Gov: 0.33
# Épisode 12000 terminé. Epsilon Gov: 0.30
# Épisode 13000 terminé. Epsilon Gov: 0.27
# Épisode 14000 terminé. Epsilon Gov: 0.25
# Épisode 15000 terminé. Epsilon Gov: 0.22
# Épisode 16000 terminé. Epsilon Gov: 0.20
# Épisode 17000 terminé. Epsilon Gov: 0.18
# Épisode 18000 terminé. Epsilon Gov: 0.17
# Épisode 19000 terminé. Epsilon Gov: 0.15
# Épisode 20000 terminé. Epsilon Gov: 0.14
# Épisode 21000 terminé. Epsilon Gov: 0.12
# Épisode 22000 terminé. Epsilon Gov: 0.11
# Épisode 23000 terminé. Epsilon Gov: 0.10
# Épisode 24000 terminé. Epsilon Gov: 0.09
# Épisode 25000 terminé. Epsilon Gov: 0.08
# Épisode 26000 terminé. Epsilon Gov: 0.07
# Épisode 27000 terminé. Epsilon Gov: 0.07
# Épisode 28000 terminé. Epsilon Gov: 0.06
# Épisode 29000 terminé. Epsilon Gov: 0.06
# Épisode 30000 terminé. Epsilon Gov: 0.05
# Épisode 31000 terminé. Epsilon Gov: 0.05
# Épisode 32000 terminé. Epsilon Gov: 0.04
# Épisode 33000 terminé. Epsilon Gov: 0.04
# Épisode 34000 terminé. Epsilon Gov: 0.03
# Épisode 35000 terminé. Epsilon Gov: 0.03
# Épisode 36000 terminé. Epsilon Gov: 0.03
# Épisode 37000 terminé. Epsilon Gov: 0.02
# Épisode 38000 terminé. Epsilon Gov: 0.02
# Épisode 39000 terminé. Epsilon Gov: 0.02
# Épisode 40000 terminé. Epsilon Gov: 0.02
# Épisode 41000 terminé. Epsilon Gov: 0.02
# Épisode 42000 terminé. Epsilon Gov: 0.01
# Épisode 43000 terminé. Epsilon Gov: 0.01
# Épisode 44000 terminé. Epsilon Gov: 0.01
# Épisode 45000 terminé. Epsilon Gov: 0.01
# Épisode 46000 terminé. Epsilon Gov: 0.01
# Épisode 47000 terminé. Epsilon Gov: 0.01
# Épisode 48000 terminé. Epsilon Gov: 0.01
# Épisode 49000 terminé. Epsilon Gov: 0.01
# Épisode 50000 terminé. Epsilon Gov: 0.01
# Épisode 51000 terminé. Epsilon Gov: 0.01
# Épisode 52000 terminé. Epsilon Gov: 0.01
# Épisode 53000 terminé. Epsilon Gov: 0.01
# Épisode 54000 terminé. Epsilon Gov: 0.01
# Épisode 55000 terminé. Epsilon Gov: 0.01
# Épisode 56000 terminé. Epsilon Gov: 0.01
# Épisode 57000 terminé. Epsilon Gov: 0.01
# Épisode 58000 terminé. Epsilon Gov: 0.01
# Épisode 59000 terminé. Epsilon Gov: 0.01
# Épisode 60000 terminé. Epsilon Gov: 0.01
# Épisode 61000 terminé. Epsilon Gov: 0.01
# Épisode 62000 terminé. Epsilon Gov: 0.01
# Épisode 63000 terminé. Epsilon Gov: 0.01
# Épisode 64000 terminé. Epsilon Gov: 0.01
# Épisode 65000 terminé. Epsilon Gov: 0.01
# Épisode 66000 terminé. Epsilon Gov: 0.01
# Épisode 67000 terminé. Epsilon Gov: 0.01
# Épisode 68000 terminé. Epsilon Gov: 0.01
# Épisode 69000 terminé. Epsilon Gov: 0.01
# Épisode 70000 terminé. Epsilon Gov: 0.01
# Épisode 71000 terminé. Epsilon Gov: 0.01
# Épisode 72000 terminé. Epsilon Gov: 0.01
# Épisode 73000 terminé. Epsilon Gov: 0.01
# Épisode 74000 terminé. Epsilon Gov: 0.01
# Épisode 75000 terminé. Epsilon Gov: 0.01
# Épisode 76000 terminé. Epsilon Gov: 0.01
# Épisode 77000 terminé. Epsilon Gov: 0.01
# Épisode 78000 terminé. Epsilon Gov: 0.01
# Épisode 79000 terminé. Epsilon Gov: 0.01
# Épisode 80000 terminé. Epsilon Gov: 0.01
# Épisode 81000 terminé. Epsilon Gov: 0.01
# Épisode 82000 terminé. Epsilon Gov: 0.01
# Épisode 83000 terminé. Epsilon Gov: 0.01
# Épisode 84000 terminé. Epsilon Gov: 0.01
# Épisode 85000 terminé. Epsilon Gov: 0.01
# Épisode 86000 terminé. Epsilon Gov: 0.01
# Épisode 87000 terminé. Epsilon Gov: 0.01
# Épisode 88000 terminé. Epsilon Gov: 0.01
# Épisode 89000 terminé. Epsilon Gov: 0.01
# Épisode 90000 terminé. Epsilon Gov: 0.01
# Épisode 91000 terminé. Epsilon Gov: 0.01
# Épisode 92000 terminé. Epsilon Gov: 0.01
# Épisode 93000 terminé. Epsilon Gov: 0.01
# Épisode 94000 terminé. Epsilon Gov: 0.01
# Épisode 95000 terminé. Epsilon Gov: 0.01
# Épisode 96000 terminé. Epsilon Gov: 0.01
# Épisode 97000 terminé. Epsilon Gov: 0.01
# Épisode 98000 terminé. Epsilon Gov: 0.01
# Épisode 99000 terminé. Epsilon Gov: 0.01

# %%
#ancienne version des epsilon decay 

'''
# --- INITIALISATION DES LISTES (Indispensable pour éviter le NameError) ---
history_sw = []
history_pol = []

# --- Initialisation ---
env = env_module.EcoSystem()
gov = agent_module.GovernmentAgent()
firms = [agent_module.FirmAgent() for _ in range(5)]


for ep in range(50000):
    state_vec = env.reset()
    pollution = state_vec[2]
    done = False
    ep_sw = 0 # Pour cumuler le bien-être social de l'épisode
    
    for step in range(50):
        gov_idx = gov.get_action(pollution)
        a_type, a_val = gov.actions[gov_idx]
        gov.decay_epsilon()
        q_indices, q_vals = [], []
        for f in firms:
            idx = f.get_action(a_type, a_val)
            q_indices.append(idx)
            q_vals.append(f.actions[idx])
            
        next_state_vec, reward_gov, rewards_firms = env.step_multi_firms(a_type, a_val, q_vals)
        next_pollution = next_state_vec[2]
        
        # Apprentissage...
        for i in range(5):
            firms[i].learn(a_type, a_val, q_indices[i], rewards_firms[i])
        gov.learn(pollution, gov_idx, reward_gov, next_pollution)
        
        pollution = next_pollution
        ep_sw += reward_gov # On cumule le SW du step
    
    # --- ENREGISTREMENT DES RÉSULTATS ---
    history_sw.append(ep_sw)        # On stocke le total du SW de l'épisode
    history_pol.append(pollution)   # On stocke la pollution finale de l'épisode
    
    for f in firms: f.decay_epsilon()
    if ep % 1000 == 0:
        print(f"Épisode {ep} terminé. Epsilon Gov: {gov.epsilon:.2f}")
'''
# Out:
# Épisode 0 terminé. Epsilon Gov: 1.00
# Épisode 1000 terminé. Epsilon Gov: 0.95
# Épisode 2000 terminé. Epsilon Gov: 0.90
# Épisode 3000 terminé. Epsilon Gov: 0.86
# Épisode 4000 terminé. Epsilon Gov: 0.82
# Épisode 5000 terminé. Epsilon Gov: 0.78
# Épisode 6000 terminé. Epsilon Gov: 0.74
# Épisode 7000 terminé. Epsilon Gov: 0.70
# Épisode 8000 terminé. Epsilon Gov: 0.67
# Épisode 9000 terminé. Epsilon Gov: 0.64
# Épisode 10000 terminé. Epsilon Gov: 0.61
# Épisode 11000 terminé. Epsilon Gov: 0.58
# Épisode 12000 terminé. Epsilon Gov: 0.55
# Épisode 13000 terminé. Epsilon Gov: 0.52
# Épisode 14000 terminé. Epsilon Gov: 0.50
# Épisode 15000 terminé. Epsilon Gov: 0.47
# Épisode 16000 terminé. Epsilon Gov: 0.45
# Épisode 17000 terminé. Epsilon Gov: 0.43
# Épisode 18000 terminé. Epsilon Gov: 0.41
# Épisode 19000 terminé. Epsilon Gov: 0.39
# Épisode 20000 terminé. Epsilon Gov: 0.37
# Épisode 21000 terminé. Epsilon Gov: 0.35
# Épisode 22000 terminé. Epsilon Gov: 0.33
# Épisode 23000 terminé. Epsilon Gov: 0.32
# Épisode 24000 terminé. Epsilon Gov: 0.30
# Épisode 25000 terminé. Epsilon Gov: 0.29
# Épisode 26000 terminé. Epsilon Gov: 0.27
# Épisode 27000 terminé. Epsilon Gov: 0.26
# Épisode 28000 terminé. Epsilon Gov: 0.25
# Épisode 29000 terminé. Epsilon Gov: 0.23
# Épisode 30000 terminé. Epsilon Gov: 0.22
# Épisode 31000 terminé. Epsilon Gov: 0.21
# Épisode 32000 terminé. Epsilon Gov: 0.20
# Épisode 33000 terminé. Epsilon Gov: 0.19
# Épisode 34000 terminé. Epsilon Gov: 0.18
# Épisode 35000 terminé. Epsilon Gov: 0.17
# Épisode 36000 terminé. Epsilon Gov: 0.17
# Épisode 37000 terminé. Epsilon Gov: 0.16
# Épisode 38000 terminé. Epsilon Gov: 0.15
# Épisode 39000 terminé. Epsilon Gov: 0.14
# Épisode 40000 terminé. Epsilon Gov: 0.14
# Épisode 41000 terminé. Epsilon Gov: 0.13
# Épisode 42000 terminé. Epsilon Gov: 0.12
# Épisode 43000 terminé. Epsilon Gov: 0.12
# Épisode 44000 terminé. Epsilon Gov: 0.11
# Épisode 45000 terminé. Epsilon Gov: 0.11
# Épisode 46000 terminé. Epsilon Gov: 0.10
# Épisode 47000 terminé. Epsilon Gov: 0.10
# Épisode 48000 terminé. Epsilon Gov: 0.10
# Épisode 49000 terminé. Epsilon Gov: 0.10

# %%
# 1. Voir si ça a convergé
plot_convergence(history_sw, history_pol)

# 2. Voir comment la Firme 1 (coût faible) et la Firme 5 (coût élevé) réagissent
plot_firm_strategy(firms[0], "Firme 1 (Coût Faible)")
plot_firm_strategy(firms[4], "Firme 5 (Coût Élevé)")

# 3. Voir ce que l'État a appris
plot_gov_decisions(gov)

# %%
def plot_policy_responses(firms_list):
    # Valeurs de politiques définies dans le Gouvernement
    tax_values = [0, 1, 2, 3, 4, 5]
    quota_values = [2, 4, 6, 8, 10]
    
    plt.figure(figsize=(15, 6))
    styles = ['-', '--', ':', '-.', (0, (3, 5, 1, 5))]

    # --- GRAPHIQUE 1 : RÉACTION À LA TAXE ---
    plt.subplot(1, 2, 1)
    for i, f in enumerate(firms_list):
        responses = []
        for v in tax_values:
            state_key = (0, float(v))
            if state_key in f.q_table:
                best_action_idx = np.argmax(f.q_table[state_key])
                responses.append(f.actions[best_action_idx])
            else:
                responses.append(None)
        
        plt.plot(tax_values, responses, marker='o', label=f"Firme {i+1} (a_i={1+i})")
    
    plt.title("Production apprise vs Niveau de Taxe")
    plt.xlabel("Valeur de la Taxe")
    plt.ylabel("Quantité produite $q$")
    plt.grid(True, alpha=0.3)
    plt.legend()

    # --- GRAPHIQUE 2 : RÉACTION AU QUOTA ---
    plt.subplot(1, 2, 2)
    for i, f in enumerate(firms_list):
        responses = []
        for v in quota_values:
            state_key = (1, float(v))
            if state_key in f.q_table:
                best_action_idx = np.argmax(f.q_table[state_key])
                responses.append(f.actions[best_action_idx])
            else:
                responses.append(None)
        
        plt.plot(quota_values, responses, marker='s', label=f"Firme {i+1}")

    plt.title("Production apprise vs Niveau de Quota")
    plt.xlabel("Valeur du Quota (Législatif)")
    plt.ylabel("Quantité produite $q$")
    plt.grid(True, alpha=0.3)
    plt.legend()

    plt.tight_layout()
    plt.show()

# %%
# Après l'entraînement :
plot_policy_responses(firms)

# %%
gov.epsilon = 0.0
for f in firms:
    f.epsilon = 0.0

# %%
test_sw = []
test_pol = []
test_policies = []
test_total_q = []

n_test_episodes = 200
n_steps = 50

for ep in range(n_test_episodes):
    state_vec = env.reset()
    pollution = state_vec[2]
    ep_sw = 0
    
    last_policy = None
    
    for step in range(n_steps):
        gov_idx = gov.get_action(pollution)
        a_type, a_val = gov.actions[gov_idx]
        last_policy = (a_type, a_val)
        
        q_vals = []
        for f in firms:
            idx = f.get_action(a_type, a_val)
            q_vals.append(f.actions[idx])
        
        next_state_vec, reward_gov, rewards_firms = env.step_multi_firms(a_type, a_val, q_vals)
        pollution = next_state_vec[2]
        ep_sw += reward_gov
    
    test_sw.append(ep_sw)
    test_pol.append(pollution)
    test_policies.append(last_policy)
    test_total_q.append(env.total_q)

# %%
print("SW moyen test :", np.mean(test_sw))
print("SW écart-type test :", np.std(test_sw))

print("Pollution finale moyenne :", np.mean(test_pol))
print("Pollution finale écart-type :", np.std(test_pol))

print("Dernières politiques choisies (exemples) :", test_policies[:10])
# Out:
# SW moyen test : 1676.6868723738664
# SW écart-type test : 0.0
# Pollution finale moyenne : 199.0763191526521
# Pollution finale écart-type : 0.0
# Dernières politiques choisies (exemples) : [(1, 4), (1, 4), (1, 4), (1, 4), (1, 4), (1, 4), (1, 4), (1, 4), (1, 4), (1, 4)]

# %%
plt.figure(figsize=(12, 4))

plt.subplot(1, 2, 1)
plt.plot(test_sw)
plt.title("Social welfare en test")
plt.xlabel("Épisode de test")
plt.ylabel("SW")

plt.subplot(1, 2, 2)
plt.plot(test_pol)
plt.title("Pollution finale en test")
plt.xlabel("Épisode de test")
plt.ylabel("Pollution")

plt.tight_layout()
plt.show()
